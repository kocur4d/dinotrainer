# %%
# %run Agent.ipynb
# Out:
# Using TensorFlow backend.

# %%
from time import sleep

# %%
agent = Agent()
agent.setup()

# %%
agent.isDead()
# Out:
# False

# %%
agent.start()

while(agent.isDead() == False):
    agent.react()
    sleep(0.1)
# Out:
# action none
# action none
# action none
# action none
# action none
# action none
# action none
# action none
# action up

# %%
agent.isDead()
# Out:
# True

# %%
agent.show_gallery()

# %%
agent.score()
# Out:
# 5.973067

# %%
agent2 = Agent()
agent2.setup()
agent2.start()

while(agent2.isDead() == False):
    agent2.react()
    sleep(0.1)
    
agent2.score()
# Out:
# action down
# action up
# action down
# action none
# action up
# action down
# action none
# action up
# action up
# action down
# 6.837024

# %%
a = [agent, agent2]

# %%
ag = max(a, key=lambda a: a.score())

# %%
ag

# %%
ag.score()
# Out:
# 6.837024

# %%
a = []
a.append(1)

# %%
a
# Out:
# [1]
